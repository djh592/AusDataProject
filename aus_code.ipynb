# %% [markdown]
# # Australia data
# Data source: Compustat Global - Fundamentals Annual
#
# Date range: 1987-06 - 2023-08
#
# Identifiers:
# - datadate
# - Global Company Key (gvkey)
# - International Security ID (ISIN)
# - FYEAR -- Data Year - Fiscal (FYEAR)
# - SEDOL (SEDOL)
# - CONML -- Company Legal Name (CONML)
# - FIC -- ISO Country Code - Incorporation (FIC)
# - CITY -- City (CITY)
# - SIC -- Standard Industry Classification Code (SIC)

# %%
import pandas as pd
import numpy as np
import json

# %%
def winsorize_series(s: pd.Series, limits=[0.05, 0.95], msk=None) -> pd.Series:
    s = s.copy()
    q = s.quantile(limits)
    if isinstance(q, pd.Series) and len(q) == 2:
        if msk is None:
            s[s < q.iloc[0]] = q.iloc[0]
            s[s > q.iloc[1]] = q.iloc[1]
        else:
            s[s < q.iloc[0]] = msk
            s[s > q.iloc[1]] = msk
    return s

# %%
# load data
df = pd.read_csv(
    "./data/wovz34pxq1fe4z1r.csv").dropna(subset=["datadate", "fyear", "isin"])
df.rename(columns={"fyear": "year"}, inplace=True)
df
# Out:
#         gvkey    year    datadate       at   capx      ceq     che      dlc  \
# 0        5302  1996.0  1996-06-30    4.724  0.862    4.595   1.117    0.064
# 1        5302  1997.0  1997-06-30    8.626  1.596    7.523   1.412    0.033
# 2        5302  1998.0  1998-06-30    8.234  0.773    6.391   0.530    0.000
# 3        5302  1999.0  1999-06-30    9.182  0.272    9.093   2.182    0.000
# 4        5302  2000.0  2000-06-30    7.837  0.347    5.529   3.007    0.000
# ...       ...     ...         ...      ...    ...      ...     ...      ...
# 47542  356597  2022.0  2022-12-31    0.144  0.015    0.115   0.122    0.000
# 47543  357325  2019.0  2019-06-30  301.823  1.916  141.464  22.701   98.527
# 47544  357325  2020.0  2020-06-30  394.393  2.138  142.849  19.171  128.876
# 47545  357325  2021.0  2021-06-30  428.724  2.360  182.128  23.244   42.663
# 47546  357325  2022.0  2022-06-30  639.556  1.585  233.820  40.597  113.962
#
#           dltt   ebitda  ...          isin    sedol    cshoi epsexcon  \
# 0        0.000   -1.341  ...  AU0000185597  BL55PB2   73.158   -0.018
# 1        0.000   -1.508  ...  AU0000185597  BL55PB2   80.157   -0.013
# 2        0.000   -2.149  ...  AU0000185597  BL55PB2  105.196   -0.046
# 3        0.000   -2.422  ...  AU0000185597  BL55PB2  107.377   -0.144
# 4        0.000   -2.092  ...  AU0000185597  BL55PB2  151.405   -0.108
# ...        ...      ...  ...           ...      ...      ...      ...
# 47542    0.000   -0.045  ...  AU0000274284  BMBR1L1      NaN      NaN
# 47543    0.000   49.001  ...  AU0000284895  BQ81P89      NaN      NaN
# 47544   40.300   66.095  ...  AU0000284895  BQ81P89      NaN      NaN
# 47545  111.616   73.885  ...  AU0000284895  BQ81P89      NaN      NaN
# 47546  147.858  134.233  ...  AU0000284895  BQ81P89      NaN      NaN
#
#       epsincon   nicon  tstkni  fic     city     sic
# 0       -0.018  -0.979     NaN  AUS  Subiaco  1040.0
# 1       -0.013  -1.076     NaN  AUS  Subiaco  1040.0
# 2       -0.046  -4.082     0.0  AUS  Subiaco  1040.0
# 3       -0.144     NaN     NaN  AUS  Subiaco  1040.0
# 4       -0.108 -11.693     NaN  AUS  Subiaco  1040.0
# ...        ...     ...     ...  ...      ...     ...
# 47542      NaN     NaN     NaN  AUS    Perth  1000.0
# 47543      NaN     NaN     NaN  AUS    Minto  5160.0
# 47544      NaN     NaN     NaN  AUS    Minto  5160.0
# 47545      NaN     NaN     NaN  AUS    Minto  5160.0
# 47546      NaN     NaN     NaN  AUS    Minto  5160.0
#
# [46010 rows x 23 columns]

# %%
market_data = pd.read_csv("./data//ifl6dljmnzoyi6g6.csv")
# keep year and month
df["datadate"] = pd.to_datetime(df["datadate"]).dt.strftime("%Y-%m")
market_data["datadate"] = pd.to_datetime(
    market_data["datadate"]).dt.strftime("%Y-%m")
market_data
# Out:
#          gvkey datadate   prccm          isin  fic
# 0         5302  2004-01  0.2000  AU0000185597  AUS
# 1         5302  2004-02  0.1750  AU0000185597  AUS
# 2         5302  2004-03  0.1400  AU0000185597  AUS
# 3         5302  2004-04  0.1500  AU0000185597  AUS
# 4         5302  2004-05  0.1200  AU0000185597  AUS
# ...        ...      ...     ...           ...  ...
# 464073  356294  2023-07  0.2250  AU0000273088  AUS
# 464074  356294  2023-06  0.1501           NaN  AUS
# 464075  356294  2023-07  0.1340           NaN  AUS
# 464076  356597  2023-06  0.2000  AU0000274284  AUS
# 464077  356597  2023-07  0.2000  AU0000274284  AUS
#
# [464078 rows x 5 columns]

# %%
# merge data
df = pd.merge(df, market_data, on=["isin", "datadate"], how="left")
df
# Out:
#        gvkey_x    year datadate       at   capx      ceq     che      dlc  \
# 0         5302  1996.0  1996-06    4.724  0.862    4.595   1.117    0.064
# 1         5302  1997.0  1997-06    8.626  1.596    7.523   1.412    0.033
# 2         5302  1998.0  1998-06    8.234  0.773    6.391   0.530    0.000
# 3         5302  1999.0  1999-06    9.182  0.272    9.093   2.182    0.000
# 4         5302  2000.0  2000-06    7.837  0.347    5.529   3.007    0.000
# ...        ...     ...      ...      ...    ...      ...     ...      ...
# 46005   356597  2022.0  2022-12    0.144  0.015    0.115   0.122    0.000
# 46006   357325  2019.0  2019-06  301.823  1.916  141.464  22.701   98.527
# 46007   357325  2020.0  2020-06  394.393  2.138  142.849  19.171  128.876
# 46008   357325  2021.0  2021-06  428.724  2.360  182.128  23.244   42.663
# 46009   357325  2022.0  2022-06  639.556  1.585  233.820  40.597  113.962
#
#           dltt   ebitda  ...  epsexcon  epsincon   nicon tstkni fic_x  \
# 0        0.000   -1.341  ...    -0.018    -0.018  -0.979    NaN   AUS
# 1        0.000   -1.508  ...    -0.013    -0.013  -1.076    NaN   AUS
# 2        0.000   -2.149  ...    -0.046    -0.046  -4.082    0.0   AUS
# 3        0.000   -2.422  ...    -0.144    -0.144     NaN    NaN   AUS
# 4        0.000   -2.092  ...    -0.108    -0.108 -11.693    NaN   AUS
# ...        ...      ...  ...       ...       ...     ...    ...   ...
# 46005    0.000   -0.045  ...       NaN       NaN     NaN    NaN   AUS
# 46006    0.000   49.001  ...       NaN       NaN     NaN    NaN   AUS
# 46007   40.300   66.095  ...       NaN       NaN     NaN    NaN   AUS
# 46008  111.616   73.885  ...       NaN       NaN     NaN    NaN   AUS
# 46009  147.858  134.233  ...       NaN       NaN     NaN    NaN   AUS
#
#           city     sic  gvkey_y  prccm  fic_y
# 0      Subiaco  1040.0      NaN    NaN    NaN
# 1      Subiaco  1040.0      NaN    NaN    NaN
# 2      Subiaco  1040.0      NaN    NaN    NaN
# 3      Subiaco  1040.0      NaN    NaN    NaN
# 4      Subiaco  1040.0      NaN    NaN    NaN
# ...        ...     ...      ...    ...    ...
# 46005    Perth  1000.0      NaN    NaN    NaN
# 46006    Minto  5160.0      NaN    NaN    NaN
# 46007    Minto  5160.0      NaN    NaN    NaN
# 46008    Minto  5160.0      NaN    NaN    NaN
# 46009    Minto  5160.0      NaN    NaN    NaN
#
# [46010 rows x 26 columns]

# %%
# drop duplicates
df = df.sort_values(by=["isin", "datadate"], ascending=[False, True])
del df["datadate"]
df = df.drop_duplicates(subset=["isin", "year"], keep="first")
df
# Out:
#        gvkey_x    year       at   capx      ceq     che     dlc   dltt  \
# 45735   351061  2020.0  113.177    NaN   71.514  43.529  21.077  0.000
# 45736   351061  2021.0  279.136    NaN  245.543  86.239     NaN    NaN
# 45737   351061  2022.0  194.821  0.066  172.375  79.493     NaN    NaN
# 2581    142795  1997.0    5.750  0.305    2.013   0.002   1.991  0.000
# 2582    142795  1998.0    7.118  0.660    3.645   0.811   2.286  0.500
# ...        ...     ...      ...    ...      ...     ...     ...    ...
# 45001   341392  2018.0    3.154    NaN    2.854     NaN     NaN    NaN
# 45002   341392  2019.0    3.280    NaN    2.880     NaN     NaN    NaN
# 45003   341392  2020.0    6.599    NaN    3.325     NaN   0.371  2.273
# 45004   341392  2021.0    6.229    NaN    3.432     NaN   0.300  1.973
# 45005   341392  2022.0    6.522    NaN    3.359     NaN   0.284  2.317
#
#        ebitda  ppent  ...  epsexcon  epsincon   nicon tstkni  fic_x  \
# 45735  84.181  0.052  ...       NaN       NaN     NaN    NaN    AUS
# 45736  61.268  0.225  ...       NaN       NaN     NaN    NaN    AUS
# 45737  -8.901  0.174  ...   -0.2064   -0.2064 -91.474    NaN    AUS
# 2581   -2.396  5.664  ...   -0.3407   -0.3407  -5.400    NaN    AUS
# 2582   -0.851  6.170  ...   -0.1498   -0.0531  -0.493    NaN    AUS
# ...       ...    ...  ...       ...       ...     ...    ...    ...
# 45001   0.721  0.330  ...    0.1453    0.1453   0.441    NaN    AUS
# 45002   0.667  0.277  ...    0.1348    0.1348   0.397    NaN    AUS
# 45003   1.454  2.791  ...    0.2568    0.2568   0.717    NaN    AUS
# 45004   0.876  3.045  ...    0.1116    0.1116   0.304    NaN    AUS
# 45005   0.724  3.627  ...    0.0483    0.0483   0.131    NaN    AUS
#
#              city     sic   gvkey_y  prccm fic_y
# 45735      Austin  7372.0       NaN    NaN   NaN
# 45736      Austin  7372.0  351061.0  2.040   AUS
# 45737      Austin  7372.0  351061.0  0.635   AUS
# 2581      Coomera  4950.0       NaN    NaN   NaN
# 2582      Coomera  4950.0       NaN    NaN   NaN
# ...           ...     ...       ...    ...   ...
# 45001  Canterbury  6020.0  341392.0  0.800   AUS
# 45002  Canterbury  6020.0  341392.0  0.850   AUS
# 45003  Canterbury  6020.0  341392.0  0.860   AUS
# 45004  Canterbury  6020.0  341392.0  0.950   AUS
# 45005  Canterbury  6020.0  341392.0  0.950   AUS
#
# [45762 rows x 25 columns]

# %%
import os
if not os.path.exists('output'):
    os.makedirs('output')

# %% [markdown]
# 1. Capex $_{t}$ / AT $_{t-1}$

# %%
df["CapitalExpenditures/TotalAsset"] = df["capx"] / df["at"] * 100
df["CapitalExpenditures/TotalAsset"] = winsorize_series(
    df["CapitalExpenditures/TotalAsset"], limits=[0.01, 0.99], msk=None)
df[["isin", "year", "CapitalExpenditures/TotalAsset"]].describe().T
# Out:
#                                   count         mean        std          min  \
# year                            45762.0  2010.424413   7.606380  1987.000000
# CapitalExpenditures/TotalAsset  34122.0    10.850830  19.106846     0.012321
#
#                                         25%          50%          75%  \
# year                            2005.000000  2011.000000  2017.000000
# CapitalExpenditures/TotalAsset     1.098059     4.048133    12.678921
#
#                                         max
# year                            2023.000000
# CapitalExpenditures/TotalAsset   140.361832

# %%
result_json = df[["isin", "year", "CapitalExpenditures/TotalAsset"
                 ]].to_json(orient='split', index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "CapitalExpenditures/TotalAsset",
    "variable_description": "Capital Expenditures (CAPX) / Total Assets (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_capexatratio.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 2. Capex $_{t}$ / PPENT $_{t-1}$

# %%
df["CapitalExpenditures/PropertyPlant&Equipment"] = df["capx"] / df["ppent"] * 100
# inf -> nan
df["CapitalExpenditures/PropertyPlant&Equipment"] = df["CapitalExpenditures/PropertyPlant&Equipment"].replace(np.inf, np.nan)
df["CapitalExpenditures/PropertyPlant&Equipment"] = winsorize_series(df["CapitalExpenditures/PropertyPlant&Equipment"],
                                     limits=[0.01, 0.99], msk=None)
df[["isin", "year", "CapitalExpenditures/PropertyPlant&Equipment"]].describe().T
# Out:
#                                                count         mean         std  \
# year                                         45762.0  2010.424413    7.606380
# CapitalExpenditures/PropertyPlant&Equipment  33463.0    60.509796  202.832513
#
#                                                      min          25%  \
# year                                         1987.000000  2005.000000
# CapitalExpenditures/PropertyPlant&Equipment     0.051632     8.996501
#
#                                                      50%          75%  \
# year                                         2011.000000  2017.000000
# CapitalExpenditures/PropertyPlant&Equipment    22.177858    47.038519
#
#                                                      max
# year                                         2023.000000
# CapitalExpenditures/PropertyPlant&Equipment  1771.807719

# %%
result_json = df[["isin", "year", "CapitalExpenditures/PropertyPlant&Equipment"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "CapitalExpenditures/PropertyPlant&Equipment",
    "variable_description": "Capital Expenditures (CAPX) / Property, Plant and Equipment - Total (Net) (PPENT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_capexppentratio.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 3. PPENT $_{t}$ / AT $_{t}$

# %%
df["PropertyPlant&Equipment/TotalAssets"] = df["ppent"] / df["at"] * 100
df["PropertyPlant&Equipment/TotalAssets"] = winsorize_series(df["PropertyPlant&Equipment/TotalAssets"],
                                                            limits=[0.01, 0.99], msk=None)
df[["isin", "year", "PropertyPlant&Equipment/TotalAssets"]].describe().T
# Out:
#                                        count         mean        std     min  \
# year                                 45762.0  2010.424413   7.606380  1987.0
# PropertyPlant&Equipment/TotalAssets  41862.0    31.879730  31.223828     0.0
#
#                                              25%         50%          75%  \
# year                                 2005.000000  2011.00000  2017.000000
# PropertyPlant&Equipment/TotalAssets     2.944137    21.25745    58.140005
#
#                                              max
# year                                 2023.000000
# PropertyPlant&Equipment/TotalAssets    97.575954

# %%
result_json = df[["isin", "year", "PropertyPlant&Equipment/TotalAssets"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "PropertyPlant&Equipment/TotalAssets",
    "variable_description": "Capital Expenditures (CAPX) / Property, Plant and Equipment - Total (Net) (PPENT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_ppeatratio.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 4. CASH $_{t}$ / AT $_{t - 1}$

# %%
df["Chsh/TotalAssets"] = df["che"] / df["at"] * 100
df["Chsh/TotalAssets"] = winsorize_series(df["Chsh/TotalAssets"],
                                          limits=[0.01, 0.99], msk=None)
df[["isin", "year", "Chsh/TotalAssets"]].describe().T
# Out:
#                     count         mean        std          min          25%  \
# year              45762.0  2010.424413   7.606380  1987.000000  2005.000000
# Chsh/TotalAssets  38263.0    27.044258  28.333914     0.008998     4.882468
#
#                           50%          75%          max
# year              2011.000000  2017.000000  2023.000000
# Chsh/TotalAssets    15.306915    41.868012    98.826267

# %%
result_json = df[["isin", "year", "Chsh/TotalAssets"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "Chsh/TotalAssets",
    "variable_description": "Cash and Short-Term Investments (CHE) / Total Assets (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_cashatratio.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 5. Cost of Debt: XINT $_{t}$ / (DLTT $_{t}$ + DLC $_{t}$ )

# %%
df["CostofDebt"] = df["xint"] / (df["dltt"] + df["dlc"]) * 100
# inf -> nan
df["CostofDebt"] = df["CostofDebt"].replace(np.inf, np.nan)
df["CostofDebt"] = winsorize_series(df["CostofDebt"],
                                    limits=[0.01, 0.99], msk=None)
df[["isin", "year", "CostofDebt"]].describe().T
# Out:
#               count         mean        std     min          25%          50%  \
# year        45762.0  2010.424413   7.606380  1987.0  2005.000000  2011.000000
# CostofDebt  24824.0    19.002865  54.996382     0.0     4.678667     7.317073
#
#                     75%          max
# year        2017.000000  2023.000000
# CostofDebt    11.490067   449.146137

# %%
result_json = df[["isin", "year", "CostofDebt"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "CostofDebt",
    "variable_description": "Interest and Related Expense - Total (XINT) / (Long-Term Debt - Total (DLTT) + Debt in Current Liabilities - Total (DLC)). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_costofdebt.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 6. RD $_{t}$ / AT $_{t-1}$

# %%
df["R&D/TotalAssets"] = df["xrd"] / df["at"] * 100
# inf -> nan
df["R&D/TotalAssets"] = df["R&D/TotalAssets"].replace(np.inf, np.nan)
df["R&D/TotalAssets"] = winsorize_series(df["R&D/TotalAssets"],
                                    limits=[0.01, 0.99], msk=None)
df[["isin", "year", "R&D/TotalAssets"]].describe().T
# Out:
#                    count         mean        std          min          25%  \
# year             45762.0  2010.424413   7.606380  1987.000000  2005.000000
# R&D/TotalAssets   7272.0    14.240151  26.031564     0.004702     0.624482
#
#                          50%          75%          max
# year             2011.000000  2017.000000  2023.000000
# R&D/TotalAssets     3.930721    15.509569   161.778432

# %%
result_json = df[["isin", "year", "R&D/TotalAssets"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "R&D/TotalAssets",
    "variable_description": "Research and Development Expense (XRD) / Assets - Total (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_rdatratio.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 7. ROA: NI $_{t}$ / AT $_{t-1}$

# %%
df["ROA"] = df["nicon"] / df["at"] * 100
df["ROA"] = winsorize_series(df["ROA"],
                                    limits=[0.01, 0.99], msk=None)
df[["isin", "year", "ROA"]].describe().T
# Out:
#         count         mean         std          min          25%          50%  \
# year  45762.0  2010.424413    7.606380  1987.000000  2005.000000  2011.000000
# ROA   40577.0   -38.554448  123.040678  -938.920137   -30.704637    -5.766691
#
#               75%          max
# year  2017.000000  2023.000000
# ROA      4.408872    46.454392

# %%
result_json = df[["isin", "year", "ROA"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "ROA",
    "variable_description": "Net Income (Loss) - Consolidated (NICON) / Assets - Total (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_roa.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 8. TobinQ (AT $_{t}$ + MKTVAL $_{t}$ - CEQ $_{t}$ ) / AT $_{t}$

# %%
# 用股价计算MKTVAL，这里只能算出普通股总价值
df["mktval"] = df["prccm"] * (df["cshoi"] - df["tstkni"])
df[["isin", "year", "mktval"]].describe().T
# 待验证
# Out:
#           count         mean           std          min          25%  \
# year    45762.0  2010.424413      7.606380  1987.000000  2005.000000
# mktval   1810.0  7827.316288  21153.660372     0.172372   150.751669
#
#                 50%          75%           max
# year    2011.000000  2017.000000    2023.00000
# mktval   951.250057  4032.560195  208734.11625

# %%
df["TobinQ"] = (df["at"] + df["mktval"] - df["ceq"]) / df["at"]
df["TobinQ"] = winsorize_series(df["TobinQ"],
                                limits=[0.01, 0.99], msk=None)
df[["isin", "year", "TobinQ"]].describe().T
# Out:
#           count         mean       std          min          25%          50%  \
# year    45762.0  2010.424413  7.606380  1987.000000  2005.000000  2011.000000
# TobinQ   1810.0     1.705737  1.502403     0.470896     0.998051     1.172273
#
#                 75%          max
# year    2017.000000  2023.000000
# TobinQ     1.767994     9.611434

# %%
result_json = df[["isin", "year", "TobinQ"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "TobinQ",
    "variable_description": "(Assets - Total (AT) + (Par Value - Issue (PV) * (Com Shares Outstanding - Issue (CSHOI) - Treasury Stock - Number of Common Shares - Issue (TSTKNI))) - Common/Ordinary Equity - Total (CEQ)) / Assets - Total (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_tobinq.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 9. Size: Log(AT $_{t}$ )

# %%
df["Size"] = np.log(df["at"])
# -inf -> nan
df["Size"] = df["Size"].replace(-np.inf, np.nan)
df["Size"] = winsorize_series(df["Size"],
                                limits=[0.01, 0.99], msk=None)
df[["isin", "year", "Size"]].describe().T
# Out:
# /home/djh592/dev/python/dta-process/venv/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/djh592/dev/python/dta-process/venv/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         count         mean       std          min          25%         50%  \
# year  45762.0  2010.424413  7.606380  1987.000000  2005.000000  2011.00000
# Size  45015.0     3.492874  2.473464    -2.588413     1.835058     3.20177
#
#               75%          max
# year  2017.000000  2023.000000
# Size     5.043022    10.063817

# %%
result_json = df[["isin", "year", "Size"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "Size",
    "variable_description": "Log(Assets - Total (AT)). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_size.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 10. Leverage: (DLTT $_{t}$ + DLC $_{t}$ ) / (AT $_{t-1}$ )

# %%
df["Leverage"] = (df["dltt"]+df["dlc"]) / df["at"]*100
df["Leverage"] = winsorize_series(df["Leverage"],
                              limits=[0.01, 0.99], msk=None)
df[["isin", "year", "Leverage"]].describe().T
# Out:
#             count         mean        std     min     25%          50%  \
# year      45762.0  2010.424413   7.606380  1987.0  2005.0  2011.000000
# Leverage  41295.0    23.679818  63.498423     0.0     0.0     5.057325
#
#                   75%          max
# year      2017.000000  2023.000000
# Leverage    26.102246   533.583333

# %%
result_json = df[["isin", "year", "Leverage"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "Leverage",
    "variable_description": "(Long-Term Debt - Total (DLTT) + Debt in Current Liabilities - Total (DLC)) / Assets - Total (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_leverage.json", "w") as file:
     json.dump(output_dict, file, indent=4)

# %% [markdown]
# 11. EBITDA: ETITDA $_{t}$ / AT $_{t}$

# %%
df["EBITDA"] = df["ebitda"] / df["at"]*100
df["EBITDA"] = winsorize_series(df["EBITDA"],
                              limits=[0.01, 0.99], msk=None)
df[["isin", "year", "EBITDA"]].describe().T
# Out:
#           count         mean         std          min          25%  \
# year    45762.0  2010.424413    7.606380  1987.000000  2005.000000
# EBITDA  45236.0   -37.951431  168.303534 -1414.029302   -24.732306
#
#                 50%          75%          max
# year    2011.000000  2017.000000  2023.000000
# EBITDA    -3.413552     9.615175    96.784238

# %%
result_json = df[["isin", "year", "EBITDA"
                  ]].to_json(orient="split", index=False)
result_dict = json.loads(result_json)

# %%
output_dict = {
    "varibale_name": "EBITDA",
    "variable_description": "Earnings Before Interest (EBITDA) / Assets - Total (AT). Winsorized at 1\% and 99\% level.",
    "data_source": "Compustat Global - Fundamentals Annual",
    "reference": "",
    "identifier_entity": "isin",
    "identifier_time": "year",
}
output_dict["data"] = result_dict["data"]

# %%
with open("./output/aus_ebitda.json", "w") as file:
     json.dump(output_dict, file, indent=4)
